# %%
import pandas as pd
from pandas import DataFrame, Series
import numpy as np
import sqlite3

# %%
conn = sqlite3.connect('data.sqlite')
df = pd.read_sql_query("SELECT * FROM users", conn)

# %%
df
# Out:
#    username  id  role_id                         email  \
# 0  Mnakaran   1        3          mankaran32@gmail.com
# 1    Raghav   2        1                abcd@gmail.com
# 2   raghav1   3        1                test@gmail.com
# 3   prakhar   4        1      prakharsingh13@gmail.com
# 4   raghav2   5        1           rvirmani9@gmail.com
# 5  prakhar3   6        1  upadhayayupadhayay@gmail.com
#
#                                             password  confirmed  \
# 0  pbkdf2:sha256:50000$mIk6Ao13$ed38874d331bf2e86...          0
# 1  pbkdf2:sha256:50000$3XIZzFXt$37b9245f9992c1ccd...          0
# 2  pbkdf2:sha256:50000$fXhlRkwv$c9426b14a9e34d818...          0
# 3  pbkdf2:sha256:50000$SCdMRBdv$d3f7ccdc81c95ddc2...          0
# 4  pbkdf2:sha256:50000$41v4saWs$5b21ce22510f1789c...          0
# 5  pbkdf2:sha256:50000$Gd0nZ9Ke$b84c29923e47a1523...          0
#
#                                             about_me               location  \
# ...

# %%
df[df.blood_group == 'O+'].email.count()
# Out:
# 1
